# %%
# Initialize Otter
import otter
grader = otter.Notebook("Homework_3.ipynb")

# %%
# Don't change this cell; just run it. 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#import d8error

# %% [markdown]
# # Homework 3: Pandas
#
# The main topics covered in Homework 2 are:
# <ul>
#     <li> .csv / Data Frames</li>
#     <li> Pandas</li>
# </ul>
#
# ---

# %% [markdown]
# ## Part 1: Pandas
#
# For this next part of the homework, we will be using Numpy and python's pandas library to analyze real-world data sets.
#
# We will be looking at <b>Individual Hospital Statistics for California.</b> These are non-federal, short-term, acute care hospitals in California. The dataset can be accessed directly using the following link or by the website:
# * [California Hospital Website](https://www.ahd.com/states/hospital_CA.html)
#
# Here are the data sets for both the SF and LA Hospitals:
# * [Hospitals_LA](https://docs.google.com/spreadsheets/d/1ZWb0wUIu-IV1QM8G6pHNJUHrz4rAtnYxb5aX6M-iVe0/edit?usp=sharing)
# * [Hospitals_SF](https://docs.google.com/spreadsheets/d/1VSN0961WQQGbrAugjI5-iN5FnsmYIjWYYz-tR-wWbqo/edit?usp=sharing)
#
# Note: You will already have these data sets accessible within the notebook with the names of the data sets above.
#
# Use the Pandas LIbrary, Hospitals_SF.csv, and Hospitals_LA.csv to complete the questions below.
#
#
# <b>San Francisco Hospitals (13):</b>
# <ul>
#     <li>Chinese Hospital</li>
#     <li>CPMC Davies Campus</li>
#     <li>CPMC Mission Bernal Campus & Orthopedic Institute</li>
#     <li>CPMC Van Ness Campus</li>
#     <li>Kaiser Permanente San Francisco Medical Center</li>
#     <li>Laguna Honda Hospital and Rehabilitation Center</li>
#     <li>San Francisco VA Medical Center</li>
#     <li>UCSF Betty Irene Moore Women's Hospital</li>
#     <li>UCSF Health Hyde Hospital</li>
#     <li>UCSF Health Stanyan Hospital</li>
#     <li>UCSF Helen Diller Medical Center at Parnassus Heights</li>
#     <li>UCSF Mission Bay Campus</li>
#     <li>Zuckerberg San Francisco General Hospital and Trauma Center</li>
# </ul>
#
# <b>Los Angeles Hospitals (18):</b>
# <ul>
#     <li>Adventist Health White Memorial</li>
#     <li>California Hospital Medical Center</li>
#     <li>Cedars-Sinai Medical Center</li>
#     <li>CHA Hollywood Presbyterian Medical Center</li>
#     <li>Docs Surgical Hospital</li>
#     <li>East Los Angeles Doctors Hospital</li>
#     <li>LA Downtown Medical Center Downtown Campus</li>
#     <li>Los Angeles Community Hospital</li>
#     <li>Los Angeles General Medical Center</li>
#     <li>Los Angeles Medical Center</li>
#     <li>Martin Luther King, Jr. Community Hospital</li>
#     <li>PIH Health Good Samaritan Hospital</li>
#     <li>Ronald Reagan UCLA Medical Center</li>
#     <li>The Keck Hospital of USC</li>
#     <li>UCLA Mattel Children's Hospital</li>
#     <li>USC Norris Comprehensive Cancer Center</li>
#     <li>West Los Angeles Medical Center</li>
#     <li>West Los Angeles VA Medical Center</li>
# </ul>

# %% [markdown]
# ---

# %% [markdown]
# ### Sum methods - Pandas
#
# This section will focus on using Pandas `sum()` methods directly on our data sets.

# %% [markdown]
# <div class="alert alert-info">
#     <b>1. Use the Pandas .sum() method to calculate total Staffed_Beds for San Francisco Hospitals.</b>
# </div>

# %%
...
staffed_beds_SF = ...
print(staffed_beds_SF)

# %%
grader.check("q1")

# %% [markdown]
# <div class="alert alert-info">
#     <b>2. Use the Pandas .sum() method to calculate total Staffed_Beds for Los Angeles Hospitals.</b>
# </div>

# %%
...
staffed_beds_LA = ...
print(staffed_beds_LA)

# %%
grader.check("q2")

# %% [markdown]
# <div class="alert alert-info">
#     <b>3. Use the Pandas .sum() method to calculate total Total_discharges for San Francisco Hospitals.</b>
# </div>

# %%
...
total_discharges_SF = ...
print(total_discharges_SF)

# %%
grader.check("q3")

# %% [markdown]
# <div class="alert alert-info">
#     <b>4. Use the Pandas .sum() method to calculate total Total_discharges for Los Angeles Hospitals.</b>
# </div>

# %%
...
total_discharges_LA = ...
print(total_discharges_LA)

# %%
grader.check("q4")

# %% [markdown]
# <div class="alert alert-info">
#     <b>5. Use the Pandas .sum() method to calculate total Gross_Patient_Revenue for San Francisco Hospitals.</b>
# </div>

# %%
...
gpr_SF = ...
print(gpr_SF)

# %%
grader.check("q5")

# %% [markdown]
# <div class="alert alert-info">
#     <b>6. Use the Pandas .sum() method to calculate total Gross_Patient_Revenue for Los Angeles Hospitals.</b>
# </div>

# %%
...
gpr_LA = ...
print(gpr_LA)

# %%
grader.check("q6")

# %% [markdown]
# ---
# ### Mean & Median Methods - Pandas
#
# This section will focus on using Pandas `mean()` method directly on our data sets.

# %% [markdown]
# <div class="alert alert-info">
#     <b>7. Find the mean for total Gross_Patient_Revenue for San Francisco Hospitals.</b>
# </div>

# %%
...
mean_gpr_SF = ...
print(mean_gpr_SF)

# %%
grader.check("q7")

# %% [markdown]
# <div class="alert alert-info">
#     <b>8. Find the mean for total Gross_Patient_Revenue for Los Angeles Hospitals.</b>
# </div>

# %%
...
mean_gpr_LA = ...
print(mean_gpr_LA)

# %%
grader.check("q8")

# %% [markdown]
# <div class="alert alert-info">
#     <b>9. Find the median for total Gross_Patient_Revenue for San Francisco Hospitals.</b>
# </div>

# %%
...
median_gpr_SF = ...
print(median_gpr_SF)

# %%
grader.check("q9")

# %% [markdown]
# <div class="alert alert-info">
#     <b>10. Find the median for total Gross_Patient_Revenue for Los Angeles Hospitals.</b>
# </div>

# %%
...
median_gpr_LA = ...
print(median_gpr_LA)

# %%
grader.check("q10")

# %% [markdown]
# <div class="alert alert-info">
#     <b>11. Compare and contrast the mean number of staffed beds for San Francisco and Los Angeles Hospitals. Are the results the same results you received for homework 2?
# </b>
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# ---
# ### Visualization Methods - Histograms
#
# In this section, we will be using Pandas and Matplotlib to graph histograms of certain columns of our data sets.

# %% [markdown]
# <div class="alert alert-info">
#     <b>12. Create a Histogram for the Gross_Patient_Revenue variable/column in the data set for San Francisco Hospitals.
#
# [Hints*** panda and matplotlib example]
#
# </b>
# </div>

# %%
# Type answer here

# %% [markdown]
# <div class="alert alert-info">
#     <b>13. Looking at the histograms Gross_Patient_Revenue. Estimate the typical revenue for hospitals in San Francisco. Is the mean value you calculated above similar to your estimate based upon the histogram?
# </b>
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# <div class="alert alert-info">
#     <b>14. Create a Histogram for the Gross_Patient_Revenue variable/column in the data set for Los Angeles Hospitals.
#
# [Hints*** panda and matplotlib example]
#
# </b>
# </div>

# %%
# Type answer here

# %% [markdown]
# <div class="alert alert-info">
#     <b>15. Looking at the histograms Gross_Patient_Revenue. Estimate the typical revenue for hospitals in Los Angeles Hospital.  Is the mean value you calculated above similar to your estimate based upon the histogram?
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False, run_tests=True)
