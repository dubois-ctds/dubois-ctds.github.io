# %% [markdown]
# ## Lecture 02

# %% [markdown]
# ## Review from Lab/Challenge

# %%
# Exercise 1
x = 10
x + 2
x
# Out:
# 10

# %%
# Exercise 2
y = x - 4
y
# Out:
# 6

# %%
# Exercise 3
# recall ** is exponentiation/power
y = max(x, y ** 2)
y
# Out:
# 63340286662973277706162286946811886609896461828096

# %% [markdown]
# Exercise 4. What if we ran the previous cell again?

# %% [markdown]
# ## Numeric Data Types
#
# (adapted from Data 8 Lecture 4, Fall 2024)

# %% [markdown]
# ### `int` and `float`

# %%
1 + 3
# Out:
# 4

# %%
1234567 * 890
# Out:
# 1098764630

# %%
1234567 ** 20
# Out:
# 67653969256331495649068283811346298491907584134058827077138045699295881910674491882264924512105825607973877575534562149601

# %%
0.00003
# Out:
# 3e-05

# %% [markdown]
# ---

# %%
2024
# Out:
# 2024

# %%
1012 * 2.0
# Out:
# 2024.0

# %%
10 / 4
# Out:
# 2.5

# %%
# edit to have more whitespace
10 // 4
# Out:
# 2

# %% [markdown]
# ---
#
# ### More on `float` values

# %%
10/3

# %%
75892745.21548924758927498571223498230498320948320984023984
# Out:
# 75892745.21548925

# %%
75892745.215489247589274985712 - 75892745.21548925

# %%
.1 + .2
# Out:
# 0.30000000000000004

# %% [markdown]
# This is a consequence of how numbers (in particular, floats) are stored in computers. There’s nothing we can really do about it, but you should be aware of it!

# %% [markdown]
# ---
#
# ### Every value has a **data type**

# %%
type(10 // 2)
# Out:
# int

# %%
a = 10

# %%
type(a * 2.0)
# Out:
# float

# %%
type(1012 * 2)
# Out:
# int

# %%
type(4048/2)
# Out:
# float

# %%
type(1234567 ** 20)
# Out:
# int

# %%
type(max)
# Out:
# builtin_function_or_method

# %%
type(abs)
# Out:
# builtin_function_or_method

# %%
type(abs(20))
# Out:
# int

# %%
abs(-20.45687)
# Out:
# 20.45687

# %% [markdown]
# ---
#
# ## Strings

# %%
'Flavor'
# Out:
# 'Flavor'

# %%
type('Flavor')
# Out:
# str

# %%
Flavor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 Flavor
#
# NameError: name 'Flavor' is not defined

# %%
'I wouldn't ever ignore my homework'
# Out:
#   Cell In[49], line 1
#     'I wouldn't ever ignore my homework'
#                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"I wouldn't ever ignore my homework"
# Out:
# "I wouldn't ever ignore my homework"

# %%
'"'
# Out:
# '"'

# %% [markdown]
# ---
#
# ### `+` with strings: **string concatenation**

# %%
"I" + "wouldn't ever ignore my homework"
# Out:
# "Iwouldn't ever ignore my homework"

# %%
"I" + " wouldn't ever ignore my homework"
# Out:
# "I wouldn't ever ignore my homework"

# %%
"Ben" + " 10"
# Out:
# 'Ben 10'

# %%
"Ben" + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 "Ben" + 10
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ---
# ### `len` function: returns number of characters in a string

# %%
len("hello world")
# Out:
# 11

# %%
s = "Ben" + "10"

# %%
len(s)
# Out:
# 5

# %%
# bonus...not tested
'ha' * 100
# Out:
# 'hahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahaha'

# %% [markdown]
# ---
#
# ## Typecasting

# %% [markdown]
# ### Strings $\rightarrow$ Numbers

# %%
int("12")
# Out:
# 12

# %%
float("1.2")
# Out:
# 1.2

# %%
int(float('3.0'))
# Out:
# 3

# %%
float(int('3'))
# Out:
# 3.0

# %% [markdown]
# ---
#
# ### Any value can be converted to a string

# %%
str(5)

# %%
str(10)

# %%
'Ben ' + str(10)

# %% [markdown]
# ---
#
# ### Conversion between number types

# %%
float(1)

# %%
2 + float(8)

# %%
2 + 8.0

# %% [markdown]
# ---
#
# ### "Conversions"

# %% [markdown]
# This will fail:

# %%
float("one point two")

# %% [markdown]
# This will "work", but you will lose the decimal place:

# %%
int(1.2)
# Out:
# 1

# %%
int(1.23)

int(1.6)

# %%
round(1.6)
# Out:
# 2

# %% [markdown]
# ---
#
# ### "Quick" check

# %%
lucky = 15 + 0.01
lucky = str(int(lucky)) + "3"
int(lucky) - 1

# %% [markdown]
# ---
#
# ## Application: Tuberculosis Incidence

# %% [markdown]
# From the [CDC](https://www.cdc.gov/mmwr/volumes/71/wr/mm7112a1.htm?s_cid=mm7112a1_w#T1_down):
# <br>
# <br>
#
# **Tuberculosis Cases by U.S. Jurisdiction**
#
# | U.S. Jurisdiction | No. of TB Cases | &nbsp; | &nbsp; | TB Incidence | &nbsp; | &nbsp; |
# | --- | --- | --- | --- | --- | --- | --- |
# | &nbsp; | **2019** | **2020** | **2021** | **2019** | **2020** | **2021** |
# | Total | 8,900 | 7,173 | 7,860 | 2.71 | 2.16 | 2.37|
# | ... | ... | ... | ... | ... | ... | ... |
#
# **U.S. Population by State**
#
# | &nbsp; | Population | &nbsp; | &nbsp; |
# | --- | --- | --- | --- |
# | &nbsp; | **2019** | **2020** | **2021** |
# | Total | 328,239,523 | 331,501,080 | 331,893,745 |
# | ... | ... |... | .. |
#
# > Reported TB incidence (cases per 100,000 persons) increased 9.4%, from **2.2** during 2020 to **2.4** during 2021 but was lower than incidence during 2019 (2.7).
#
# * **Incidence**: "Cases per 100,000 persons" What does this rate mean?
# * Can you validate the US tuberculosis incidence for 2020?

# %%
pop_2020 = ...
tb_2020 = ...

# %% [markdown]
# **Try 1**: cases per 100,000

# %%
incidence_2020 = tb_2020/100000
incidence_2020

# %% [markdown]
# <br/><br/><br/><br/><br/><br/>
#
#
#
# **Try 2**: cases per population (a rate that "makes sense")

# %%
incidence_2020 = ...
incidence_2020

# %% [markdown]
# <br/><br/><br/><br/><br/><br/>
#
#
#
#
#
# **Try 3**: cases per (groups of 100,000)

# %%
incidence_2020 = ...
incidence_2020

# %% [markdown]
# Reflect on Try 3:
#
# <details>
#
# * More interpretable rate than Try 2!
# * Python names helped us abstract away the numeric details and focus on the conceptual data definition.
#
# </details>

# %% [markdown]
# Try verifying 2021's TB incidence:

# %%
# compute incidence as cases per 100k
pop_2021 = 331893745
tb_2021 = 7860
incidence_2021 = ...
incidence_2021
